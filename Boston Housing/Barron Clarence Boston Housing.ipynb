# %% [markdown]
# ### CPE 4903 Boston Housing LR using Normal Equation ###

# %% [markdown]
# # Linear Regression on Boston Housing Dataset
#
# This data was originally a part of UCI Machine Learning Repository and has been removed now. This data also ships with the scikit-learn library.
# There are 506 samples and 13 feature variables in this data-set. The objective is to predict the value of prices of the house using the given features.
#
# The description of all the features is given below:
#
#   **CRIM**: Per capita crime rate by town
#
#   **ZN**: Proportion of residential land zoned for lots over 25,000 sq. ft
#
#   **INDUS**: Proportion of non-retail business acres per town
#
#   **CHAS**: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#
#   **NOX**: Nitric oxide concentration (parts per 10 million)
#
#   **RM**: Average number of rooms per dwelling
#
#   **AGE**: Proportion of owner-occupied units built prior to 1940
#
#   **DIS**: Weighted distances to five Boston employment centers
#
#   **RAD**: Index of accessibility to radial highways
#
#   **TAX**: Full-value property tax rate per $10,000
#
#   **B**: 1000(Bk - 0.63)², where Bk is the proportion of [people of African American descent] by town
#
#   **LSTAT**: Percentage of lower status of the population
#
#   **MEDV**: Median value of owner-occupied homes in $1000s

# %% [markdown]
# I**mport the required Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
#import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# **Load the Boston Housing DataSet from csv file downloaded from Kaggle.com**

# %%
# download data from https://www.kaggle.com/puxama/bostoncsv
boston = pd.read_csv('Boston.csv')

# %%
boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %% [markdown]
# **Load the data into pandas dataframe**

# %% [markdown]
# **Data preprocessing**

# %%
# check for missing values in all the columns
boston.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
# drop extra useless column
boston=boston.drop(['Unnamed: 0'],axis=1)
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# **Data Visualization**

# %%
boston['medv']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
plt.hist(boston['medv'], density=True, bins=30)  # `density=False` would make counts
plt.ylabel('Histogram')
plt.xlabel('MEDV');

# %% [markdown]
# **Correlation matrix**

# %%
# compute the pair wise correlation for all columns  
correlation_matrix = boston.corr()

# %%
# Display and review correclation of each feature to target 'medv'. Higher than 0 and closer to -1/+1 is viable
correlation_matrix.style.background_gradient(cmap = 'coolwarm') # let's color code correlation
# Out:
# <style type="text/css">
# #T_8d6ce_row0_col0, #T_8d6ce_row1_col1, #T_8d6ce_row2_col2, #T_8d6ce_row3_col3, #T_8d6ce_row4_col4, #T_8d6ce_row5_col5, #T_8d6ce_row6_col6, #T_8d6ce_row7_col7, #T_8d6ce_row8_col8, #T_8d6ce_row9_col9, #T_8d6ce_row10_col10, #T_8d6ce_row11_col11, #T_8d6ce_row12_col12, #T_8d6ce_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8d6ce_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_8d6ce_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_8d6ce_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_8d6ce_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_8d6ce_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_8d6ce_row0_col6, #T_8d6ce_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_8d6ce_row0_col7, #T_8d6ce_row11_col4, #T_8d6ce_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_8d6ce_row0_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_8d6ce_row0_col9, #T_8d6ce_row2_col8, #T_8d6ce_row8_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_8d6ce_row0_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8d6ce_row0_col11, #T_8d6ce_row13_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_8d6ce_row0_col12 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_8d6ce_row0_col13, #T_8d6ce_row9_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col2, #T_8d6ce_row1_col6, #T_8d6ce_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col4, #T_8d6ce_row1_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col5, #T_8d6ce_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_8d6ce_row1_col7, #T_8d6ce_row9_col4, #T_8d6ce_row13_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col8, #T_8d6ce_row5_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col10, #T_8d6ce_row9_col3, #T_8d6ce_row13_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_8d6ce_row1_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_8d6ce_row1_col12, #T_8d6ce_row5_col2, #T_8d6ce_row6_col3, #T_8d6ce_row10_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col1, #T_8d6ce_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col3, #T_8d6ce_row8_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col5, #T_8d6ce_row7_col12 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col7, #T_8d6ce_row4_col1, #T_8d6ce_row11_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col10, #T_8d6ce_row13_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_8d6ce_row2_col11, #T_8d6ce_row11_col9, #T_8d6ce_row12_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col12, #T_8d6ce_row6_col12, #T_8d6ce_row12_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_8d6ce_row2_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8d6ce_row3_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_8d6ce_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8d6ce_row3_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_8d6ce_row3_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_8d6ce_row3_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_8d6ce_row3_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_8d6ce_row3_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_8d6ce_row3_col8, #T_8d6ce_row3_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_8d6ce_row3_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_8d6ce_row3_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8d6ce_row3_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_8d6ce_row3_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8d6ce_row4_col0, #T_8d6ce_row12_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_8d6ce_row4_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col3, #T_8d6ce_row5_col3, #T_8d6ce_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col5, #T_8d6ce_row13_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col7, #T_8d6ce_row6_col1, #T_8d6ce_row7_col2, #T_8d6ce_row7_col4, #T_8d6ce_row7_col6, #T_8d6ce_row7_col8, #T_8d6ce_row7_col9, #T_8d6ce_row8_col11, #T_8d6ce_row9_col11, #T_8d6ce_row10_col3, #T_8d6ce_row11_col0, #T_8d6ce_row12_col5, #T_8d6ce_row12_col13, #T_8d6ce_row13_col0, #T_8d6ce_row13_col10, #T_8d6ce_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_8d6ce_row4_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8d6ce_row4_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_8d6ce_row4_col12, #T_8d6ce_row8_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_8d6ce_row4_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8d6ce_row5_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_8d6ce_row5_col4, #T_8d6ce_row13_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_8d6ce_row5_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_8d6ce_row5_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_8d6ce_row5_col9, #T_8d6ce_row10_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_8d6ce_row5_col10, #T_8d6ce_row12_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8d6ce_row5_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_8d6ce_row5_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_8d6ce_row5_col13 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_8d6ce_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_8d6ce_row6_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_8d6ce_row6_col10, #T_8d6ce_row7_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8d6ce_row6_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_8d6ce_row6_col13 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_8d6ce_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8d6ce_row7_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8d6ce_row7_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_8d6ce_row7_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_8d6ce_row7_col13 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_8d6ce_row8_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_8d6ce_row8_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_8d6ce_row8_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_8d6ce_row8_col7, #T_8d6ce_row9_col13, #T_8d6ce_row12_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_8d6ce_row8_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_8d6ce_row8_col10 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_8d6ce_row8_col12 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_8d6ce_row8_col13, #T_8d6ce_row11_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8d6ce_row9_col0, #T_8d6ce_row12_col9 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_8d6ce_row9_col1 {
#   background-colo

# %% [markdown]
# **Observations**
#
#
#
#
# *   From the above coorelation plot we can see that **MEDV** is strongly correlated to **LSTAT**, **RM**
#
# *  **RAD** and **TAX** are stronly correlated, so we don't include this in our features together to avoid multi-colinearity

# %%
x1 = boston['lstat']
x2 = boston['rm']
x3 = boston['ptratio']
y = boston['medv']
plt.figure(figsize=(20, 5))
plt.subplot(131)
plt.scatter(x1, y, marker='o')
plt.xlabel('LSTAT')
plt.ylabel('Median Value MEDV ($1000s)')
plt.subplot(132)
plt.scatter(x2, y, marker='o')
plt.xlabel('RM')
plt.ylabel('Median Value MEDV ($1000s)')
plt.subplot(133)
plt.scatter(x3, y, marker='o')
plt.xlabel('PTRATIO')
plt.ylabel('Median Value MEDV ($1000s)')
plt.show()

# %% [markdown]
# **Train the model using Normal Equation**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Prepare the data for training**

# %%
x1 = boston['rm'].values #create numpy vectors
x2 = boston['lstat'].values
x3 = boston['ptratio'].values
Y = boston['medv'].values
m = len(x1)
nx = 3  # number of features
Y = Y.reshape(m,1)
X = np.block([x1.reshape(m,1), x2.reshape(m,1), x3.reshape(m,1)]) #useful block command to construct bigger matrix consisting of smaller ones

# %%
Y.shape
# Out:
# (506, 1)

# %% [markdown]
# **Split the data into training and testing sets**

# %%
from sklearn.model_selection import train_test_split

# splits the training and test data set in 80% : 20%
# assign random_state to any value.This ensures consistency.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
m_train = len(Y_train)
m_test = len(Y_test)
X_train = np.block([np.ones((m_train,1)), X_train])
X_test = np.block([np.ones((m_test,1)), X_test])
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 4)
# (102, 4)
# (404, 1)
# (102, 1)

# %%
X_train
# Out:
# array([[ 1.   ,  5.701, 18.35 , 21.   ],
#        [ 1.   ,  7.923,  3.16 , 13.6  ],
#        [ 1.   ,  5.957, 20.62 , 20.2  ],
#        ...,
#        [ 1.   ,  5.67 , 17.6  , 19.2  ],
#        [ 1.   ,  6.326, 10.97 , 18.6  ],
#        [ 1.   ,  5.936,  5.57 , 22.   ]])

# %%
temp1 = np.linalg.inv(np.dot(X_train.T,X_train))
temp2 = np.dot(X_train.T,Y_train)
theta = np.dot(temp1, temp2)
print(theta)
# Out:
# [[23.68107027]
#  [ 3.9169303 ]
#  [-0.64697098]
#  [-0.95483295]]

# %%
y_train_predict = np.dot(X_train,theta)
y_test_predict = np.dot(X_test,theta)

y_error = Y_train - y_train_predict
m = len(y_error)
J = np.dot(y_error.T, y_error)/m
print('The train MSE is: %6.2f'% J)

y_error = Y_test - y_test_predict
m = len(y_error)
J = np.dot(y_error.T, y_error)/m
print('The test MSE is: %6.2f'% J)
# Out:
# The train MSE is:  28.13
# The test MSE is:  24.15

# %%
# plotting the y_test vs y_pred
# ideally should have been a straight linear (slope =1) line
plt.figure(1)
plt.scatter(Y_test, y_test_predict)
plt.plot(Y_test, Y_test)
plt.xlabel('y')
plt.ylabel('yhat')

plt.figure(2)
plt.hist(Y, color = 'r', label='MEDV')
plt.hist(Y_test-y_test_predict,  label='Errors')
plt.legend(loc="upper left")
plt.show()

# %%
  print("Sample   label          predicted        %error")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(20):
    print ("%5.0f %6.0f %15.0f %15.0f" % (i, Y_test[i], y_test_predict[i], (Y_test[i] - y_test_predict[i])*100/Y_test[i]))
# Out:
# Sample   label          predicted        %error
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     0     38              37               3
#     1     28              28              -1
#     2     23              26             -16
#     3     14               1              92
#     4     35              32              10
#     5     10               8              24
#     6     24              27             -14
#     7     29              28               3
#     8     23              26             -16
#     9     23              20              12
#    10     33              32               5
#    11     19              22             -13
#    12     20              23             -14
#    13     36              30              17
#    14     24              27              -9
#    15     17              21             -20
#    16     18               0              98
#    17     20              22             -13
#    18     20              13              35
#    19     15              20             -36

# %% [markdown]
# # # 2 Data Inputs vs 3 Data Inputs

# %% [markdown]
# The difference between two and three inputs is the data becoming more precise. Since PTRATIO has a correlation of .5, the addition of the new feature caused the data to come closer to the Line of Best Fit for the data. With more accurate data, this can help future prediction making by the program by following the pattern of the market. If we add more data points within that .5 correlation, the data will get tighter and the program will become more accurate and taking ouyt outliers as well. We can see this due to a decrease in the MSE, which means the data is more accurate.
